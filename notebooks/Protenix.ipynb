# %%
# !pip install protenix
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 39.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.4/389.4 kB 34.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.1/441.1 kB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 99.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 43.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 62.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 116.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 16.7 MB/s eta 0:00:00
# ...

# %%
# !protenix predict --input /content/test.json --out_dir /content/test_out --use_msa_server
# Out:
# Try to find the ccd cache data in the code directory for inference.
# [2025-05-13 09:14:35,291] [INFO] [real_accelerator.py:239:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# 2025-05-13 09:14:38,202 [/usr/local/lib/python3.11/dist-packages/runner/batch_inference.py:296] INFO runner.batch_inference: run infer with input=/content/test.json, out_dir=/content/test_out, cycle=10, step=200, sample=5, use_msa_server=True
# 2025-05-13 09:14:38,202 [/usr/local/lib/python3.11/dist-packages/runner/batch_inference.py:212] INFO runner.batch_inference: will infer with 1 jsons
# 2025-05-13 09:14:38,210 [/usr/local/lib/python3.11/dist-packages/runner/inference.py:159] INFO runner.inference: Distributed environment: world size: 1, global rank: 0, local rank: 0
# 2025-05-13 09:14:38,211 [/usr/local/lib/python3.11/dist-packages/runner/inference.py:65] INFO root: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ...

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import shutil
shutil.copytree('/content/test_out/2_21_0', "/content/gdrive/MyDrive/Protenix/2_21_0")
# Out:
# '/content/gdrive/MyDrive/Protenix/2_21_0'
